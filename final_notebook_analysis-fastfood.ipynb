# %%
import bs4 as bs
import urllib.request
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import json 
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
# Reading the html file
source = urllib.request.urlopen('https://en.wikipedia.org/wiki/Demographics_of_Toronto_neighbourhoods').read()

# Finding the table
soup = bs.BeautifulSoup(source, 'html.parser')
tables = soup.findAll('table', attrs={'class':'wikitable sortable'})

data = [] 

for table in tables:

    # Get all table rows
    table_rows = table.find_all('tr')

    # Taking the column names of the table
    ths = table_rows[0].find_all('th')
    cols =[th.text.strip().replace(" ", "") for th in ths]

    # Extracting all the data in the table
    table_rows[0]
    for tr in table_rows:
        tds = tr.find_all('td')
        row = [td.text.strip() for td in tds]
        if len(row) > 0:
            data.append(row)

# %%
ncols = ['Neighbourhood','Municipality','Population','LandArea','Density','PopulationChange','AvgIncome','Commuting','Renters','SecondLng']
df_table = pd.DataFrame(data, columns=cols)[(cols[0:2]+cols[3:11])]
df_table.columns = ncols
df_table.head()
# Out:
#                           Neighbourhood Municipality Population LandArea  \
# 0                         Crescent Town           EY      8,157      0.4
# 1  Governor's Bridge/Bennington Heights           EY      2,112     1.87
# 2                               Leaside           EY     13,876     2.81
# 3                     O'Connor–Parkview           EY     17,740     4.94
# 4                         Old East York           EY     52,220     7.94
#
#   Density PopulationChange AvgIncome Commuting Renters         SecondLng
# 0  20,393            -10.0    23,021      24.5    20.3   Bengali (18.1%)
# 1    1129              4.0   129,904       7.1    13.3     Polish (1.4%)
# 2    4938              3.0    82,670       9.7    10.5  Bulgarian (0.4%)
# 3    3591             -6.1    33,517      15.8    19.4       Urdu (3.2%)
# 4    6577             -4.6    33,172      22.0    19.1      Greek (4.3%)

# %% [markdown]
# ## Data Cleaning
#
# We can see that raw table have numbers as text and also SecondLng Column needs spliting to the Language and the corresponding percentage. Let's clean the dataset by removing and converting numeric columns.
# 1. Remove empty lines in the dataset.
# 2. Remove the summary column at the bottom of the table.
# 3. Replace Municipality code with the name.
# 4. Split SecondLng to two columns.
# 5. Convert all numbers to float values by removing commas in the string.

# %%
# Removing empty lines in the dataset and the summary column at the bottom of the table.
df_table = df_table[~(df_table['Municipality']=='')].copy()
# Converting all numbers to float values by removing commas in the string.
df_table[df_table.columns[2:-1]] = df_table[df_table.columns[2:-1]].replace({',':''},regex=True).apply(pd.to_numeric,1)
# Split SecondLng to two columns.
df_table[['SecondLng','SecondLngPct']] = df_table['SecondLng'].str.split('(',expand=True)
df_table['SecondLngPct'] = df_table['SecondLngPct'].replace({'%\)':''},regex=True).apply(pd.to_numeric,1)
# Replacing Municipality code with the name.
df_table['Municipality'] = df_table['Municipality'].replace({'OCoT':'Old City of Toronto',
                          'S':'Scarborough',
                          'NY':'North York',
                          'E':'Etobicoke',
                          'Y':'York',
                          'EY':'East York'})
print('Datatypes of the dataset')
print(str(df_table.dtypes))
df_table.head()
df_table.to_csv("demographics.csv", index=False)
# Out:
# Datatypes of the dataset
# Neighbourhood        object
# Municipality         object
# Population          float64
# LandArea            float64
# Density             float64
# PopulationChange    float64
# AvgIncome           float64
# Commuting           float64
# Renters             float64
# SecondLng            object
# SecondLngPct        float64
# dtype: object

# %% [markdown]
# ### Reading from the previously saved csv file which has Lat, Lng

# %%
demographic_data =  pd.read_csv("demographics.csv")

# %%
neighborhood_data = pd.read_csv('latlng.csv')
neighborhood_data.head()
# Out:
#   PostalCode           Borough                                Neighbourhood  \
# 0        M3A        North York                                    Parkwoods
# 1        M4A        North York                             Victoria Village
# 2        M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3        M6A        North York             Lawrence Manor, Lawrence Heights
# 4        M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494

# %% [markdown]
# ### Foursqure credentials

# %% [markdown]
# ### First we visulaize the locations of each neighborhood in Toronto
#
# Lets use folium to show where each of the neighborhood is located in the map.

# %%
address = 'City of Toronto, ON'

geolocator = Nominatim(user_agent="TN_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of City of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of City of Toronto are 43.6534817, -79.3839347.

# %%
# Lets create markers for all the neighbourhoods in Toronto in a Folium map which is centered on Toronto
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10.2)

# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhood_data['Latitude'], neighborhood_data['Longitude'], neighborhood_data['Borough'], neighborhood_data['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_779d3ec10dd849d2a574766daeda5e22%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_779d3ec10dd849d2a574766daeda5e22%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_779d3ec10dd849d2a574766daeda5e22%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_779d3ec10dd849d2a574766daeda5e22%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# # Exploring Neighborhoods in Toronto
#
# ## 1.1 Getting venue list for each neighbourhood
# First lets create a function to get data from Foursqure api.

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_combined_list=[]
    print('Retriving venues for all the Neighborhoods')
    for name, lat, lng in zip(names, latitudes, longitudes):

            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_combined_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])
        
    print('Data collected from Foursqure API')

    nearby_venues = pd.DataFrame([item for venue_list in venues_combined_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(neighborhood_data['Neighbourhood'],neighborhood_data['Latitude'],neighborhood_data['Longitude'])
# Out:
# Retriving venues for all the Neighborhoods
# Data collected from Foursqure API

# %%
toronto_venues.to_csv("venues.csv", index=False)

# %% [markdown]
# Let's check how many venues were returned for each neighborhood

# %%
toronto_venues[['Neighborhood','Venue','Venue Category']].groupby('Neighborhood').count()
# Out:
#                                                     Venue  Venue Category
# Neighborhood
# Agincourt                                               4               4
# Alderwood, Long Branch                                  8               8
# Bathurst Manor, Wilson Heights, Downsview North        20              20
# Bayview Village                                         4               4
# Bedford Park, Lawrence Manor East                      23              23
# Berczy Park                                            62              62
# Birch Cliff, Cliffside West                             4               4
# Brockton, Parkdale Village, Exhibition Place          100             100
# Business reply mail Processing Centre, South Ce...     16              16
# CN Tower, King and Spadina, Railway Lands, Harb...     16              16
# Caledonia-Fairbanks                                     4               4
# Canada Post Gateway Processing Centre                  13              13
# Cedarbrae                                               8               8
# Central Bay Street                                     68              68
# Christie                                               15              15
# Church and Wellesley                                   79              79
# Clarks Corners, Tam O'Shanter, Sullivan                11              11
# Cliffside, Cliffcrest, Scarborough Village West         2               2
# Commerce Court, Victoria Hotel                        100             100
# Davisville                                             34              34
# Davisville North                                        9               9
# Del Ray, Mount Dennis, Keelsdale and Silverthorn        6               6
# Don Mills                                              27              27
# Dorset Park, Wexford Heights, Scarborough Town ...      6               6
# Downsview                                              17              17
# Dufferin, Dovercourt Village                           57              57
# East Toronto, Broadview North (Old East York)           2               2
# Eringate, Bloordale Gardens, Old Burnhamthorpe,...      8               8
# Fairview, Henry Farm, Oriole                           63              63
# First Canadian Place, Underground city                100             100
# Forest Hill North & West, Forest Hill Road Park         4               4
# Garden District, Ryerson                              100             100
# Glencairn                                               4               4
# Golden Mile, Clairlea, Oakridge                         8               8
# Guildwood, Morningside, West Hill                       9               9
# Harbourfront East, Union Station, Toronto Islands     100             100
# High Park, The Junction South                         100             100
# Hillcrest Village                                       5               5
# Humber Summit                                           2               2
# Humberlea, Emery                                        1               1
# Humewood-Cedarvale                                      4               4
# India Bazaar, The Beaches West                         22              22
# Kennedy Park, Ionview, East Birchmount Park             5               5
# Kensington Market, Chinatown, Grange Park              67              67
# Kingsview Village, St. Phillips, Martin Grove G...      4               4
# Lawrence Manor, Lawrence Heights                       15              15
# Lawrence Park                                           3               3
# Leaside                                                32              32
# Little Portugal, Trinity                              100             100
# Malvern, Rouge                                          1               1
# Milliken, Agincourt North, Steeles East, L'Amor...      4               4
# Mimico NW, The Queensway West, South of Bloor, ...     14              14
# Moore Park, Summerhill East                             1               1
# New Toronto, Mimico South, Humber Bay Shores           10              10
# North Park, Maple Leaf Park, Upwood Park                4               4
# North Toronto West,  Lawrence Park                     18              18
# Northwest, West Humber - Clairville                     5               5
# Northwood Park, York University                         6               6
# Old Mill South, King's Mill Park, Sunnylea, Hum...      2               2
# Parkdale, Roncesvalles                                 57              57
# Parkview Hill, Woodbine Gardens                        11              11
# Parkwoods                                               4               4
# Queen's Park, Ontario Provincial Government            33              33
# Regent Park, Harbourfront                              47              47
# Richmond, Adelaide, King                              100             100
# Rosedale                                                4               4
# Roselawn                                                2               2
# Rouge Hill, Port Union, Highland Creek                  2               2
# Runnymede, Swansea                                     57              57
# Runnymede, The Junction North                           3               3
# Scarborough Village                                     1               1
# South Steeles, Silverstone, Humbergate, Jamesto...      9               9
# St. James Town                                         90              90
# St. James Town, Cabbagetown                            45              45
# Steeles West, L'Amoreaux West                          11              11
# Stn A PO Boxes                                         98              98
# Studio District                                        36              36
# Summerhill West, Rathnelly, South Hill, Forest ...    100             100
# The Annex, North Midtown, Yorkville                    21              21
# The Beaches                                             4               4
# The Danforth West, Riverdale                           41              41
# The Kingsway, Montgomery Road, Old Mill North           1               1
# Thorncliffe Park                                       21              21
# Toronto Dominion Centre, Design Exchange              100             100
# University of Toronto, Harbord                         33              33
# Victoria Village                                        5               5
# West Deane Park, Princess Gardens, Martin Grove...      2               2
# Westmount                                               9               9
# Weston                                                  3               3
# Wexford, Maryvale                                       4               4
# Willowdale, Newtonbrook                                 1               1
# Willowdale, Willowdale East                            32              32
# Willowdale, Willowdale West                             5               5
# Woburn                                                  3               3
# Woodbine Heights                                        8               8
# York Mills West                                         3               3
# York Mills, Silver Hills                                1               1

# %% [markdown]
# Let's find out how many unique categories can be curated from all the returned venues

# %%
print('There are {} uniques categories.'.format(toronto_venues['Venue Category'].nunique()))
# Out:
# There are 285 uniques categories.

# %% [markdown]
# # 1.2 Analysing Fast Food Resturent Distribution

# %%
# Extracting fast food places
fastfood_places = toronto_venues.query("`Venue Category` == 'Fast Food Restaurant'")

# %%
print(f"There are {fastfood_places.shape[0]} fast food resturants in Torronto area")
fastfood_places
# Out:
# There are 32 fast food resturants in Torronto area
#                                            Neighborhood  \
# 1                                             Parkwoods
# 104                                      Malvern, Rouge
# 150                            Garden District, Ryerson
# 566                                   Hillcrest Village
# 603                                    Thorncliffe Park
# 636                            Richmond, Adelaide, King
# 801                        Fairview, Henry Farm, Oriole
# 802                        Fairview, Henry Farm, Oriole
# 807                        Fairview, Henry Farm, Oriole
# 829                        Fairview, Henry Farm, Oriole
# 950                            Little Portugal, Trinity
# 1152           Toronto Dominion Centre, Design Exchange
# 1309                     India Bazaar, The Beaches West
# 1408                     Commerce Court, Victoria Hotel
# 1499                  Bedford Park, Lawrence Manor East
# 1506   Del Ray, Mount Dennis, Keelsdale and Silverthorn
# 1507   Del Ray, Mount Dennis, Keelsdale and Silverthorn
# 1530                        Willowdale, Willowdale East
# 1592                      High Park, The Junction South
# 1711                 North Toronto West,  Lawrence Park
# 1950            Clarks Corners, Tam O'Shanter, Sullivan
# 2034  Summerhill West, Rathnelly, South Hill, Forest...
# 2146       New Toronto, Mimico South, Humber Bay Shores
# 2159  South Steeles, Silverstone, Humbergate, Jamest...
# 2163                      Steeles West, L'Amoreaux West
# 2167                      Steeles West, L'Amoreaux West
# 2263                                     Stn A PO Boxes
# 2400             First Canadian Place, Underground city
# 2501                               Church and Wellesley
# 2508                               Church and Wellesley
# 2516  Business reply mail Processing Centre, South C...
# 2535  Mimico NW, The Queensway West, South of Bloor,...
#
#       Neighborhood Latitude  Neighborhood Longitude                   Venue  \
# 1                 43.753259              -79.329656                     KFC
# 104               43.806686              -79.194353                 Wendy’s
# 150               43.657162              -79.378937         Crepe Delicious
# 566               43.803762              -79.363452          New York Fries
# 603               43.705369              -79.349372                     A&W
# 636               43.650571              -79.384568     The Burger's Priest
# 801               43.778517              -79.346556       Bourbon St. Grill
# 802               43.778517              -79.346556                     KFC
# 807               43.778517              -79.346556              McDonald's
# 829               43.778517              -79.346556            Fit For Life
# 950               43.653226              -79.383184         Crepe Delicious
# 1152              43.647177              -79.381576              iQ Food Co
# 1309              43.668999              -79.315572     The Burger's Priest
# 1408              43.648198              -79.379817              iQ Food Co
# 1499              43.733283              -79.419750              McDonald's
# 1506              43.691116              -79.476013              McDonald's
# 1507              43.691116              -79.476013  New York Fried Chicken
# 1530              43.770120              -79.408493                 Wendy’s
# 1592              43.653226              -79.383184         Crepe Delicious
# 1711              43.715383              -79.405678                     A&W
# 1950              43.781638              -79.304302                     KFC
# 2034              43.653226              -79.383184         Crepe Delicious
# 2146              43.605647              -79.501321              McDonald's
# 2159              43.739416              -79.588437              McDonald's
# 2163              43.799525              -79.318389                     KFC
# 2167              43.799525              -79.318389              McDonald's
# 2263              43.646435              -79.374846              iQ Food Co
# 2400              43.648429              -79.382280     The Burger's Priest
# 2501              43.665860              -79.383160                     A&W
# 2508              43.665860              -79.383160              McDonald's
# 2516              43.662744              -79.321558             Chick-n-Joy
# 2535              43.628841              -79.520999              McDonald's
#
#       Venue Latitude  Venue Longitude        Venue Category
# 1          43.754387       -79.333021  Fast Food Restaurant
# 104        43.807448       -79.199056  Fast Food Restaurant
# 150        43.654536       -79.380889  Fast Food Restaurant
# 566        43.803664       -79.363905  Fast Food Restaurant
# 603        43.706275       -79.344670  Fast Food Restaurant
# 636        43.648643       -79.387539  Fast Food Restaurant
# 801        43.778276       -79.343241  Fast Food Restaurant
# 802        43.777600       -79.344200  Fast Food Restaurant
# 807        43.778407       -79.343574  Fast Food Restaurant
# 829        43.779352       -79.350568  Fast Food Restaurant
# 950        43.654536       -79.380889  Fast Food Restaurant
# 1152       43.647482       -79.379104  Fast Food Restaurant
# 1309       43.666731       -79.315556  Fast Food Restaurant
# 1408       43.647482       -79.379104  Fast Food Restaurant
# 1499       43.732540       -79.419796  Fast Food Restaurant
# 1506       43.692926       -79.479982  Fast Food Restaurant
# 1507       43.688473       -79.480948  Fast Food Restaurant
# 1530       43.768461       -79.412377  Fast Food Restaurant
# 1592       43.654536       -79.380889  Fast Food Restaurant
# 1711       43.715149       -79.399944  Fast Food Restaurant
# 1950       43.780400       -79.300700  Fast Food Restaurant
# 2034       43.654536       -79.380889  Fast Food Restaurant
# 2146       43.602464       -79.498859  Fast Food Restaurant
# 2159       43.741757       -79.584230  Fast Food Restaurant
# 2163       43.798938       -79.318854  Fast Food Restaurant
# 2167       43.798249       -79.318167  Fast Food Restaurant
# 2263       43.647482       -79.379104  Fast Food Restaurant
# 2400       43.648643       -79.387539  Fast Food Restaurant
# 2501       43.666415       -79.378235  Fast Food Restaurant
# 2508       43.668854       -79.385962  Fast Food Restaurant
# 2516       43.665181       -79.321403  Fast Food Restaurant
# 2535       43.630007       -79.518041  Fast Food Restaurant

# %%
# Lets create markers for all the neighbourhoods in Toronto in a Folium map which is centered on Toronto
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10.2)

# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhood_data['Latitude'], neighborhood_data['Longitude'], neighborhood_data['Borough'], neighborhood_data['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.3,
        opacity=0.3,
        parse_html=False).add_to(map_toronto) 
    
for lat, lng, venue, neighborhood in zip(fastfood_places['Neighborhood Latitude'], fastfood_places['Neighborhood Longitude'], fastfood_places['Venue'], fastfood_places['Neighborhood']):
    label = '{}, {}'.format(neighborhood, venue)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='r',
        fill_opacity=0.9,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_931e986abbbd4bd3b4564efbbd8061a5%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_931e986abbbd4bd3b4564efbbd8061a5%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_931e986abbbd4bd3b4564efbbd8061a5%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_931e986abbbd4bd3b4564efbbd8061a5%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# We can see that fast food resturents are mostly located in the city center areas, and there are good places to put new fast food resturents in the city.

# %%
#Ranking Neighbohoods with most fastfood resturants
fast_neigh = fastfood_places.groupby('Neighborhood')['Venue'].count().sort_values(ascending=False).to_frame().reset_index()
fast_neigh
# Out:
#                                          Neighborhood  Venue
# 0                        Fairview, Henry Farm, Oriole      4
# 1                                Church and Wellesley      2
# 2                       Steeles West, L'Amoreaux West      2
# 3    Del Ray, Mount Dennis, Keelsdale and Silverthorn      2
# 4                         Willowdale, Willowdale East      1
# 5                      India Bazaar, The Beaches West      1
# 6   Business reply mail Processing Centre, South C...      1
# 7             Clarks Corners, Tam O'Shanter, Sullivan      1
# 8                      Commerce Court, Victoria Hotel      1
# 9              First Canadian Place, Underground city      1
# 10                           Garden District, Ryerson      1
# 11                      High Park, The Junction South      1
# 12                                  Hillcrest Village      1
# 13                           Little Portugal, Trinity      1
# 14           Toronto Dominion Centre, Design Exchange      1
# 15                                     Malvern, Rouge      1
# 16  Mimico NW, The Queensway West, South of Bloor,...      1
# 17       New Toronto, Mimico South, Humber Bay Shores      1
# 18                 North Toronto West,  Lawrence Park      1
# 19                                          Parkwoods      1
# 20                           Richmond, Adelaide, King      1
# 21  South Steeles, Silverstone, Humbergate, Jamest...      1
# 22                                     Stn A PO Boxes      1
# 23  Summerhill West, Rathnelly, South Hill, Forest...      1
# 24                                   Thorncliffe Park      1
# 25                  Bedford Park, Lawrence Manor East      1

# %% [markdown]
# Fairview, Henry Farm, Oriole contains most of the fast food resturants, followed by Church and Wellesley and Steeles West, L'Amoreaux West Neighborhoods.

# %%
fastfood_places.groupby('Venue')['Neighborhood'].count().sort_values(ascending=False).to_frame().reset_index()
# Out:
#                      Venue  Neighborhood
# 0               McDonald's             8
# 1                      KFC             4
# 2          Crepe Delicious             4
# 3               iQ Food Co             3
# 4      The Burger's Priest             3
# 5                      A&W             3
# 6                  Wendy’s             2
# 7           New York Fries             1
# 8   New York Fried Chicken             1
# 9             Fit For Life             1
# 10             Chick-n-Joy             1
# 11       Bourbon St. Grill             1

# %% [markdown]
# Most of the fast food resturents are McDonalds which is followed by KFC and Crepe Delicious.

# %% [markdown]
# Neighbourhoods without fast food resturensts. Potential locations.

# %%
temp_df = toronto_venues.copy()
temp_df["is_fastfood"] = (temp_df["Venue Category"] == 'Fast Food Restaurant')
temp_df = temp_df.groupby('Neighborhood')['is_fastfood'].sum().to_frame().reset_index()
temp_df.query("is_fastfood==0")
# Out:
#                                          Neighborhood  is_fastfood
# 0                                           Agincourt            0
# 1                              Alderwood, Long Branch            0
# 2     Bathurst Manor, Wilson Heights, Downsview North            0
# 3                                     Bayview Village            0
# 5                                         Berczy Park            0
# 6                         Birch Cliff, Cliffside West            0
# 7        Brockton, Parkdale Village, Exhibition Place            0
# 9   CN Tower, King and Spadina, Railway Lands, Har...            0
# 10                                Caledonia-Fairbanks            0
# 11              Canada Post Gateway Processing Centre            0
# 12                                          Cedarbrae            0
# 13                                 Central Bay Street            0
# 14                                           Christie            0
# 17    Cliffside, Cliffcrest, Scarborough Village West            0
# 19                                         Davisville            0
# 20                                   Davisville North            0
# 22                                          Don Mills            0
# 23  Dorset Park, Wexford Heights, Scarborough Town...            0
# 24                                          Downsview            0
# 25                       Dufferin, Dovercourt Village            0
# 26      East Toronto, Broadview North (Old East York)            0
# 27  Eringate, Bloordale Gardens, Old Burnhamthorpe...            0
# 30    Forest Hill North & West, Forest Hill Road Park            0
# 32                                          Glencairn            0
# 33                    Golden Mile, Clairlea, Oakridge            0
# 34                  Guildwood, Morningside, West Hill            0
# 35  Harbourfront East, Union Station, Toronto Islands            0
# 38                                      Humber Summit            0
# 39                                   Humberlea, Emery            0
# 40                                 Humewood-Cedarvale            0
# 42        Kennedy Park, Ionview, East Birchmount Park            0
# 43          Kensington Market, Chinatown, Grange Park            0
# 44  Kingsview Village, St. Phillips, Martin Grove ...            0
# 45                   Lawrence Manor, Lawrence Heights            0
# 46                                      Lawrence Park            0
# 47                                            Leaside            0
# 50  Milliken, Agincourt North, Steeles East, L'Amo...            0
# 52                        Moore Park, Summerhill East            0
# 54           North Park, Maple Leaf Park, Upwood Park            0
# 56                Northwest, West Humber - Clairville            0
# 57                    Northwood Park, York University            0
# 58  Old Mill South, King's Mill Park, Sunnylea, Hu...            0
# 59                             Parkdale, Roncesvalles            0
# 60                    Parkview Hill, Woodbine Gardens            0
# 62        Queen's Park, Ontario Provincial Government            0
# 63                          Regent Park, Harbourfront            0
# 65                                           Rosedale            0
# 66                                           Roselawn            0
# 67             Rouge Hill, Port Union, Highland Creek            0
# 68                                 Runnymede, Swansea            0
# 69                      Runnymede, The Junction North            0
# 70                                Scarborough Village            0
# 72                                     St. James Town            0
# 73                        St. James Town, Cabbagetown            0
# 76                                    Studio District            0
# 78                The Annex, North Midtown, Yorkville            0
# 79                                        The Beaches            0
# 80                       The Danforth West, Riverdale            0
# 81      The Kingsway, Montgomery Road, Old Mill North            0
# 84                     University of Toronto, Harbord            0
# 85                                   Victoria Village            0
# 86  West Deane Park, Princess Gardens, Martin Grov...            0
# 87                                          Westmount            0
# 88                                             Weston            0
# 89                                  Wexford, Maryvale            0
# 90                            Willowdale, Newtonbrook            0
# 92                        Willowdale, Willowdale West            0
# 93                                             Woburn            0
# 94                                   Woodbine Heights            0
# 95                                    York Mills West            0
# 96                           York Mills, Silver Hills            0

# %% [markdown]
# There are 72 Neighborhoods without a fast food resturents. So there is a real oppertunity here.

# %% [markdown]
# ## 1.3 Finding Similar Neighborhoods

# %% [markdown]
# Here we aims to cluster all the neighborhoods based on the the venue types they have. From this we can identify which neighborhoods are similar to the ones with fast food resturents. Then based on the most populous Neighborhoods we can suggest the best places to start the business.

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# one hot encoding
torronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")
# add neighborhood column back to dataframe
torronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 
# move neighborhood column to the first column
fixed_columns = list(torronto_onehot.columns)
# move the column to head of list using index, pop and insert
fixed_columns.insert(0, fixed_columns.pop(fixed_columns.index('Neighborhood')))
torronto_onehot = torronto_onehot[fixed_columns]

# Grouping by neighbohrhood
torronto_grouped = torronto_onehot.groupby('Neighborhood').mean().reset_index()

def get_population(neighbourhood):
    list_hoods = neighbourhood.lower().split(",")
    population = 0
    
    for hood in list_hoods:
        hood = hood.strip()
        population += dict_population.get(hood,0.0)
    return population

torronto_grouped['Population'] = torronto_grouped['Neighborhood'].apply(lambda x: get_population(x))

# top 10 venues per Neighborhood
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = torronto_grouped['Neighborhood']

for ind in np.arange(torronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(torronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted['Population'] = torronto_grouped['Population']

# clustering
kclusters = 30

torronto_grouped_clustering = torronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(torronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10] 
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

torronto_merged = neighborhood_data.rename(columns={'Neighbourhood': 'Neighborhood'})

# merge manhattan_grouped with manhattan_data to add latitude/longitude for each neighborhood
torronto_merged = torronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')
# torronto_merged['Cluster Labels'] = torronto_merged['Cluster Labels'].astype('int')

torronto_merged=torronto_merged[~torronto_merged['Cluster Labels'].isna()]
torronto_merged.head()
# Out:
#   PostalCode           Borough                                 Neighborhood  \
# 0        M3A        North York                                    Parkwoods
# 1        M4A        North York                             Victoria Village
# 2        M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3        M6A        North York             Lawrence Manor, Lawrence Heights
# 4        M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#     Latitude  Longitude  Cluster Labels 1st Most Common Venue  \
# 0  43.753259 -79.329656             7.0            Population
# 1  43.725882 -79.315572            18.0            Population
# 2  43.654260 -79.360636             1.0           Coffee Shop
# 3  43.718518 -79.464763            10.0            Population
# 4  43.662301 -79.389494             1.0           Coffee Shop
#
#   2nd Most Common Venue 3rd Most Common Venue       4th Most Common Venue  \
# 0     Food & Drink Shop                  Park  Construction & Landscaping
# 1     French Restaurant           Coffee Shop  Financial or Legal Service
# 2                   Pub                Bakery                        Park
# 3        Clothing Store    Miscellaneous Shop                    Boutique
# 4                  Café                 Diner          Persian Restaurant
#
#   5th Most Common Venue  6th Most Common Venue 7th Most Common Venue  \
# 0  Fast Food Restaurant       Greek Restaurant      Department Store
# 1          Hockey Arena  Portuguese Restaurant      Doner Restaurant
# 2                  Café         Breakfast Spot               Theater
# 3          Carpet Store            Coffee Shop           Event Space
# 4   Japanese Restaurant                    Bar                  Bank
#
#     8th Most Common Venue 9th Most Common Venue       10th Most Common Venue  \
# 0             Escape Room     Electronics Store  Eastern European Restaurant
# 1                   Diner        Discount Store          Distribution Center
# 2              Restaurant      Sushi Restaurant                         Bank
# 3  Furniture / Home Store             Gift Shop            Accessories Store
# 4        Sushi Restaurant    Mexican Restaurant        Portuguese Restaurant
#
#    Population
# 0     26533.0
# 1     17047.0
# 2         0.0
# 3     17519.0
# 4         0.0

# %% [markdown]
# ## 1.3 Examining Similar Neighborhoods

# %%
fast_neigh.merge(torronto_merged).head()
# Out:
#                                        Neighborhood  Venue PostalCode  \
# 0                      Fairview, Henry Farm, Oriole      4        M2J
# 1                              Church and Wellesley      2        M4Y
# 2                     Steeles West, L'Amoreaux West      2        M1W
# 3  Del Ray, Mount Dennis, Keelsdale and Silverthorn      2        M6M
# 4                       Willowdale, Willowdale East      1        M2N
#
#             Borough   Latitude  Longitude  Cluster Labels  \
# 0        North York  43.778517 -79.346556            15.0
# 1  Downtown Toronto  43.665860 -79.383160             4.0
# 2       Scarborough  43.799525 -79.318389             1.0
# 3              York  43.691116 -79.476013             0.0
# 4        North York  43.770120 -79.408493            14.0
#
#   1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0            Population        Clothing Store           Coffee Shop
# 1            Population           Coffee Shop   Japanese Restaurant
# 2  Fast Food Restaurant              Pharmacy    Chinese Restaurant
# 3            Population  Fast Food Restaurant        Discount Store
# 4            Population      Ramen Restaurant           Coffee Shop
#
#   4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 0  Fast Food Restaurant            Restaurant   Japanese Restaurant
# 1               Gay Bar      Sushi Restaurant            Restaurant
# 2        Sandwich Place                  Bank           Supermarket
# 3   Fried Chicken Joint            Restaurant        Sandwich Place
# 4   Japanese Restaurant                  Café           Pizza Place
#
#   7th Most Common Venue  8th Most Common Venue 9th Most Common Venue  \
# 0             Juice Bar                   Bank        Cosmetics Shop
# 1                 Hotel                    Pub                  Café
# 2        Breakfast Spot            Coffee Shop           Pizza Place
# 3   Dumpling Restaurant              Drugstore            Donut Shop
# 4         Shopping Mall  Vietnamese Restaurant                 Hotel
#
#      10th Most Common Venue  Population
# 0            Chocolate Shop      2790.0
# 1  Mediterranean Restaurant     13397.0
# 2         Electronics Store         0.0
# 3              Dessert Shop     21284.0
# 4         Electronics Store     43144.0

# %%
combined = fast_neigh.merge(torronto_merged).drop_duplicates(subset='Cluster Labels').reset_index(drop=True)
combined['rank'] = combined.index + 1
combined = combined[['rank','Cluster Labels']]
df1 = torronto_merged.groupby('Cluster Labels')['Neighborhood'].count().to_frame().reset_index().rename(columns={"Neighborhood":"count_all"})
df2 = fast_neigh.merge(torronto_merged).groupby('Cluster Labels')['Neighborhood'].count().to_frame().reset_index().rename(columns={"Neighborhood":"count_fastfood"})
df3 = df1.merge(df2).merge(combined)

df3['available_hoods'] = df3.count_all - df2.count_fastfood
df3.sort_values(by='rank')
# Out:
#     Cluster Labels  count_all  count_fastfood  rank  available_hoods
# 7             15.0          1               1     1                0
# 2              4.0          4               2     2                2
# 1              1.0         37              12     3               25
# 0              0.0          7               3     4                4
# 6             14.0          2               1     5                1
# 11            24.0          2               1     6                1
# 8             16.0          4               1     7                3
# 4              8.0          1               1     8                0
# 10            22.0          2               1     9                1
# 3              7.0          3               1    10                2
# 9             18.0          2               1    11                1
# 5             10.0          4               1    12                3

# %% [markdown]
# We can see that there are no neighbourhoods similar to the hood which have most number of fast food resturents. Therefore, we move to the second hood. We can see that there are 2 similar neighbourhoods which are similar.

# %%
cluster4 = torronto_merged[['PostalCode','Borough','Neighborhood','Latitude','Longitude','Population','Cluster Labels']].query("`Cluster Labels`==4.0")
cluster4 = cluster4.merge(temp_df)
cluster4
# Out:
#   PostalCode           Borough  \
# 0        M9B         Etobicoke
# 1        M4G         East York
# 2        M5M        North York
# 3        M4Y  Downtown Toronto
#
#                                         Neighborhood   Latitude  Longitude  \
# 0  West Deane Park, Princess Gardens, Martin Grov...  43.650943 -79.554724
# 1                                            Leaside  43.709060 -79.363452
# 2                  Bedford Park, Lawrence Manor East  43.733283 -79.419750
# 3                               Church and Wellesley  43.665860 -79.383160
#
#    Population  Cluster Labels  is_fastfood
# 0     13683.0             4.0            0
# 1     13876.0             4.0            0
# 2     13749.0             4.0            1
# 3     13397.0             4.0            2

# %% [markdown]
# We can see that among 4 locations 2 locations can be used for the new Fast food resturant. As they have similar population either/both places are possible selections.
# - __Neighborhood__: West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale |     __Borough__:Etobicoke
# - __Neighborhood__: Leaside	 |   __Borough__:East York

# %%
# Lets create markers for all the neighbourhoods in Toronto in a Folium map which is centered on Toronto
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10.2)

neighborhood_data = cluster4.query("`is_fastfood`==0")

# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhood_data['Latitude'], neighborhood_data['Longitude'], neighborhood_data['Borough'], neighborhood_data['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto) 
for lat, lng, venue, neighborhood in zip(fastfood_places['Neighborhood Latitude'], fastfood_places['Neighborhood Longitude'], fastfood_places['Venue'], fastfood_places['Neighborhood']):
    label = '{}, {}'.format(neighborhood, venue)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='r',
        fill_opacity=0.3,
        opacity=0.3,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_a36f331e8758405aaec31a23d204566f%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_a36f331e8758405aaec31a23d204566f%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_a36f331e8758405aaec31a23d204566f%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_a36f331e8758405aaec31a23d204566f%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# The blue locations are the best loctions for the new fast food resturant.
